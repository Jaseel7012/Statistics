# %%
import numpy as np
import pandas as pd
import seaborn as sn
df=pd.read_csv("/content/titles.csv")
display(df)
df.head()
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
df.tmdb_score.describe()
# Out:
# count    5488.000000
# mean        6.818039
# std         1.171560
# min         0.500000
# 25%         6.100000
# 50%         6.900000
# 75%         7.500000
# max        10.000000
# Name: tmdb_score, dtype: float64

# %%
sn.histplot(df.runtime,kde=True)

# %%
import pandas as pd
mean=df.imdb_votes.mean()
mean
strd_dev=df.runtime.std()
strd_dev
# Out:
# 39.4741602050739

# %%
strd_dev=df.runtime.std()
strd_dev
# Out:
# 39.4741602050739

# %%
mean-3*strd_dev
# Out:
# 3.3033601273356075

# %%
mean+3*strd_dev
# Out:
# 10.33271858986554

# %%
df[df.runtime<3.033]
# Out:
#             id                                           title   type  \
# 472    ts74931                   Kung Fu Panda Awesome Secrets   SHOW
# 478    ts98252       Dreamworks Happy Holidays from Madagascar   SHOW
# 517    ts37200                                          Trotro   SHOW
# 561    ts67595                               Pedro El Escamoso   SHOW
# 799    ts81858                                           Larva   SHOW
# 896    ts99814                                        Masameer   SHOW
# 1027    ts2161                               Angry Birds Toons   SHOW
# 1115  tm137379                                          Silent  MOVIE
# 1415   ts86021                                          Molang   SHOW
# 1423  ts119087                                   Sunny Bunnies   SHOW
# 2618   ts74765                            Daughters of Destiny   SHOW
# 2627   ts94470                                       Relatable   SHOW
# ...

# %%
df[df.runtime>10.33]
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5800  tm1040816          Momshies! Your Soul is Mine  MOVIE
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.boxplot(df.runtime)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f60c7378190>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f60c7383210>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f60c7389250>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f60c7383cd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f60c7378910>,
#   <matplotlib.lines.Line2D at 0x7f60c7378d10>]}
